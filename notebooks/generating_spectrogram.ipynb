# %% [markdown]
# # Generating spectrogram

# %% [markdown]
# Script that shows how we generate spectrograms.

# %% [markdown]
# ## Setup

# %%
from notebooks.setup_notebook_env import setup_notebook_env
setup_notebook_env()
# Out:
# Current working directory: C:\Users\pietr\Documents\studia\machine learning\intro ml nowy projekt\intro-ml-2024
# PyTorch version: 2.5.1+cu118
# Using device: cuda
# 'cuda'

# %% [markdown]
# ## Generate spectrogram from audio file
# Update `input_wav_path` as needed.

# %%
input_wav_path = './datasets/kaggle/train/train/audio/down/00b01445_nohash_0.wav'

# %% [markdown]
# ## Normal spectorgram

# %%
# %matplotlib inline
import src.scripts.spectrogram_script as spectrogram_script

args = ["-f", input_wav_path, "-s"]
spectrogram_script.main(args)
# Out:
# ./datasets/kaggle/train/train/audio/down/00b01445_nohash_0.wav

# %% [markdown]
# ## Spectrogram with mel scale

# %%
args = ["-f", input_wav_path, "-s", "-m"]
spectrogram_script.main(args)
# Out:
# ./datasets/kaggle/train/train/audio/down/00b01445_nohash_0.wav

# %% [markdown]
# ## Spectrogram with mel scale with cleaning

# %%
args = ["-f", input_wav_path, "-s", "-m","-c"]
spectrogram_script.main(args)
# Out:
# ./datasets/kaggle/train/train/audio/down/00b01445_nohash_0.wav
