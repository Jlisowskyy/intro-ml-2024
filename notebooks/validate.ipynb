# %% [markdown]
# # Validate a Trained Model

# %%
from notebooks.setup_notebook_env import setup_notebook_env
device = setup_notebook_env()
# Out:
# Current working directory: /home/wookie/Projects/intro-ml-2024
# PyTorch version: 2.5.1+cu124
# Using device: cuda

# %% [markdown]
# ## Validate an Existing Model
# Make sure `MODEL_BASE_PATH` is correctly set to the path where the model is saved.

# %%
from src.constants import *
MODEL_BASE_PATH = f"${MODELS_DIR}/<model_name>"

# %% [markdown]
# Then simply run:

# %%
# This runs the validate script entry point,
# which loads the model and prints out its validation performance
import main
main.handle_command("validate")
# Out:
# Starting validation...
# No model was loaded
# Model not found
# True
