# %% [markdown]
# # Validate a Trained Model

# %%
from notebooks.setup_notebook_env import setup_notebook_env
device = setup_notebook_env()
# Out:
# Current working directory: /home/wookie/Projects
# PyTorch version: 2.5.1+cu124
# Using device: cuda

# %% [markdown]
# ## Validate an Existing Model
# Make sure `MODEL_BASE_PATH` is correctly set in `src/constants.py` or any other code that the validation script references. That path should point to the `.pth` file containing your trained model state.

# %%
# Optionally customize relevant constants before running the training script
# Uncomment and adjust the values as needed

from src.constants import MODEL_BASE_PATH
# MODEL_BASE_PATH = "models/example_path"

# %% [markdown]
# Then simply run:

# %%
# This runs the validate script entry point,
# which loads the model and prints out its validation performance
import main
main.handle_command("validate")
# Out:
# Starting validation...
# No model was loaded
# Model not found
# True
