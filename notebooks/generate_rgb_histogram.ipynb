# %% [markdown]
# # Generating an RGB Histogram from a Spectrogram
#
# Use this notebook to directly call `generate_rgb_histogram` script on a PNG/JPG spectrogram file or a `.wav` file (which it will convert to a spectrogram first). You can also specify a directory from which random files will be selected.

# %% [markdown]
# ## Setup

# %%
from notebooks.setup_notebook_env import setup_notebook_env
setup_notebook_env()
# Out:
# Current working directory: /home/wookie/Projects/intro-ml-2024
# PyTorch version: 2.5.1+cu124
# Using device: cuda
# 'cuda'

# %% [markdown]
# ## Generate RGB Histogram

# %%
input_path = "./datasets/some_audio_file.wav"  # or .png, or directory
num_samples = 1  # for directories

args = [input_path, "-n", str(num_samples)]
# TODO

print("RGB histogram generation completed.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 12
#       9 num_samples = 1  # for directories
#      11 args = [input_path, "-n", str(num_samples)]
# ---> 12 histogram_main(args)
#      14 print("RGB histogram generation completed.")
#
# File ~/Projects/intro-ml-2024/src/scripts/generate_rgb_histogram.py:142, in main(args)
#     139 number = parsed_args.number or 1
#     141 os.makedirs(WORKING_DIR, exist_ok=True)
# --> 142 process_path_and_generate_rgb_histogram(path, number)
#     143 shutil.rmtree(WORKING_DIR)
#     145 spectrogram_path = args[0]
#
# File ~/Projects/intro-ml-2024/src/scripts/generate_rgb_histogram.py:97, in process_path_and_generate_rgb_histogram(path, number)
#      82 """
#      83 Processes the given path to generate and display RGB histograms of spectrograms.
#      84
#    (...)
#      94     None: Displays RGB histograms of spectrograms directly.
#      95 """
#      96 if not os.path.exists(path):
# ---> 97     raise ValueError(f"The specified path does not exist: {path}")
#      99 if os.path.isdir(path):
#     100     for _ in range(number):
#
# ValueError: The specified path does not exist: ./datasets/some_audio_file.wav
