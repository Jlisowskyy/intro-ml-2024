# %% [markdown]
# # Generating an RGB Histogram from a Spectrogram
#
# Use this notebook to directly call `generate_rgb_histogram` script on a PNG/JPG spectrogram file or a `.wav` file (which it will convert to a spectrogram first). You can also specify a directory from which random files will be selected.

# %% [markdown]
# ## Setup

# %%
from notebooks.setup_notebook_env import setup_notebook_env
setup_notebook_env()
# Out:
# Current working directory: /home/wookie/Projects
# PyTorch version: 2.5.1+cu124
# Using device: cuda
# 'cuda'

# %% [markdown]
# ## Generate RGB Histogram

# %% [markdown]
# Setup input directory and number of histograms to generate

# %%
input_path = "./datasets/kaggle/train/train/audio/down"  # or .png, or directory
num_samples = 2  # for directories

# %%
# %matplotlib inline
import src.scripts.generate_rgb_histogram as script

args = [input_path, "-n", str(num_samples)]

script.main(args)

print("RGB histogram generation completed.")
# Out:
# Generating RGB histogram of the spectrogram:  C:\Users\pietr\Documents\studia\machine learning\intro ml nowy projekt\intro-ml-2024\src\scripts/temp_data\00b01445_nohash_1.png
# Generating RGB histogram of the spectrogram:  C:\Users\pietr\Documents\studia\machine learning\intro ml nowy projekt\intro-ml-2024\src\scripts/temp_data\00b01445_nohash_0.png
# RGB histogram generation completed.
