# %% [markdown]
# # Training a CNN Model

# %% [markdown]
# ## Setup

# %%
from notebooks.setup_notebook_env import setup_notebook_env
device = setup_notebook_env()
# Out:
# Current working directory: /home
# PyTorch version: 2.5.1+cu124
# Using device: cuda

# %% [markdown]
# ## Run the Training Script
# By default, calling `train_main()` runs the entire training loop as defined in `src/cnn/train.py`. The constants used (epochs, learning rates, etc.) are set in `src/constants.py`.

# %%
# Optionally customize relevant constants before running the training script
# Uncomment and adjust the values as needed

from src.constants import TRAINING_EPOCHS
# TRAINING_EPOCHS = 5  

dry_run = True

# %%
import main
main.handle_command("prepare", ['dry' if dry_run else ''])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 import main
#       2 main.handle_command("prepare", ['dry' if dry_run else ''])
#
# File ~/Projects/intro-ml-2024/main.py:36
#      34 from src.scripts import data_analysis
#      35 from src.scripts import generate_rgb_histogram
# ---> 36 from src.scripts import prepare_dataset
#      37 from src.scripts import prepare_noises
#      38 from src.scripts import regenerate_csv
#
# File ~/Projects/intro-ml-2024/src/scripts/prepare_dataset.py:32
#      30 from src.pipeline.base_preprocessing_pipeline import process_audio
#      31 from src.pipeline.wav import FlattenWavIterator, AudioDataIterator
# ---> 32 from src.scripts import regenerate_csv
#      33 from src.scripts.audio_augmentation import change_pitch, add_reverb, add_echo
#      36 def gather_folders() -> list[str]:
#
# ...
