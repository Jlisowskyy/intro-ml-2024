# %% [markdown]
# # Training a CNN Model

# %% [markdown]
# ## Setup

# %%
from notebooks.setup_notebook_env import setup_notebook_env
device = setup_notebook_env()
# Out:
# Current working directory: /home/wookie/Projects/intro-ml-2024
# PyTorch version: 2.5.1+cu124
# Using device: cuda

# %% [markdown]
# ## Run the Training Script
# By default, calling `train_main()` runs the entire training loop as defined in `src/cnn/train.py`. The constants used (epochs, learning rates, etc.) are set in `src/constants.py`.

# %%
# Optionally customize relevant constants before running the training script
# Uncomment and adjust the values as needed

from src.constants import TRAINING_EPOCHS
# TRAINING_EPOCHS = 5

# %%
import main
main.handle_command('train')
# Out:
# Starting training...
# Using cuda
# split seed: 6186752650997705414
# Label names: ['down' 'go' 'left' 'no' 'off' 'on' 'right' 'stop' 'unknown1' 'unknown2'
#  'unknown3' 'unknown4' 'up' 'yes']
# Training ResidualCNN with learning rate 0.0001
# ResidualCNN(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (res_block1): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (res_block2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv_downsample): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=128, out_features=14, bias=True)
# )
# Epoch 1
#   1%|          | 0/2621 [00:00<?, ?it/s]          | 1/2621 [00:00<10:49,  4.03it/s]          | 3/2621 [00:00<05:35,  7.81it/s]          | 5/2621 [00:00<04:29,  9.69it/s]          | 7/2621 [00:00<04:03, 10.72it/s]          | 9/2621 [00:00<03:54, 11.15it/s]          | 11/2621 [00:01<03:47, 11.48it/s]          | 13/2621 [00:01<03:42, 11.70it/s]          | 15/2621 [00:01<03:38, 11.91it/s]          | 17/2621 [00:01<03:35, 12.06it/s]          | 19/2621 [00:01<03:33, 12.18it/s]          | 21/2621 [00:01<03:31, 12.28it/s]          | 23/2621 [00:02<03:33, 12.17it/s]          | 24/2621 [00:02<03:51, 11.22it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 import main
# ----> 2 main.handle_command('train')
#
# File ~/Projects/intro-ml-2024/main.py:236, in handle_command(command, args)
#     234 if command in ('train', '-t', '--train'):
#     235     print_success("Starting training...")
# --> 236     train.main()
#     237 elif command in ('validate', '-v', '--validate'):
#     238     print_success("Starting validation...")
#
# File ~/Projects/intro-ml-2024/src/cnn/train.py:242, in main()
#     238 loss_function = nn.CrossEntropyLoss()
#     239 optimiser = torch.optim.SGD(cnn.parameters(),
#     240                             lr=learning_rate, momentum=TRAINING_MOMENTUM)
# --> 242 train(cnn, train_dataloader, loss_function, optimiser, device, TRAINING_EPOCHS,
#     243       validate_dataloader, dataset.get_encoder())
#     245 now = datetime.now().strftime('%Y-%m-%dT%H:%M')
#     246 torch.save(cnn.state_dict(),
#     247            f'{MODELS_DIR}/{model_definition.model_name}_{seed}_{now}.pth')
#
# File ~/Projects/intro-ml-2024/src/cnn/train.py:146, in train(model, train_data, loss_fn, optim, device, epochs, val_data, labels)
#     144 for i in range(epochs):
#     145     print(f"Epoch {i + 1}")
# --> 146     train_single_epoch(model, train_data, loss_fn, optim, device, i == epochs - 1, labels)
#     148     if val_data is None:
#     149         continue
#
# File ~/Projects/intro-ml-2024/src/cnn/train.py:60, in train_single_epoch(model, data_loader, loss_fn, optim, device, calculate_accuracy, labels)
#      58 validator = Validator(labels)
#      59 train_loss = 0.0
# ---> 60 for input_data, target in tqdm(data_loader, colour='blue'):
#      61     input_data, target = input_data.to(device), target.to(device)
#      62     # calculate loss
#
# File ~/Projects/intro-ml-2024/.venv/lib/python3.12/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/Projects/intro-ml-2024/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File ~/Projects/intro-ml-2024/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:757, in _SingleProcessDataLoaderIter._next_data(self)
#     755 def _next_data(self):
#     756     index = self._next_index()  # may raise StopIteration
# --> 757     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758     if self._pin_memory:
#     759         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/Projects/intro-ml-2024/.venv/lib/python3.12/site-packages/torch/utils/data/_utils/fetch.py:50, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      48 if self.auto_collation:
#      49     if hasattr(self.dataset, "__getitems__") and self.dataset.__getitems__:
# ---> 50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
#      52         data = [self.dataset[idx] for idx in possibly_batched_index]
#
# File ~/Projects/intro-ml-2024/.venv/lib/python3.12/site-packages/torch/utils/data/dataset.py:420, in Subset.__getitems__(self, indices)
#     418     return self.dataset.__getitems__([self.indices[idx] for idx in indices])  # type: ignore[attr-defined]
#     419 else:
# --> 420     return [self.dataset[self.indices[idx]] for idx in indices]
#
# File ~/Projects/intro-ml-2024/src/cnn/loadset.py:138, in MultiLabelDataset.__getitem__(self, index)
#     126 """
#     127 Retrieve item from the dataset, random access
#     128
#    (...)
#     132     access location
#     133 """
#     134 spectrogram_path = join(
#     135     self.annotations['folder'][index],
#     136     self.annotations['file_name'][index][:-4] + '.npy'
#     137 )
# --> 138 spectrogram = np.load(spectrogram_path)
#     139 tens = torch.from_numpy(spectrogram).type(torch.float32)
#     140 # NOTE rot90 can stay, but I can drop it and we'll have all future models account for it
#     141 # your choice
#
# File ~/Projects/intro-ml-2024/.venv/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py:484, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     481         return format.open_memmap(file, mode=mmap_mode,
#     482                                   max_header_size=max_header_size)
#     483     else:
# --> 484         return format.read_array(fid, allow_pickle=allow_pickle,
#     485                                  pickle_kwargs=pickle_kwargs,
#     486                                  max_header_size=max_header_size)
#     487 else:
#     488     # Try a pickle
#     489     if not allow_pickle:
#
# File ~/Projects/intro-ml-2024/.venv/lib/python3.12/site-packages/numpy/lib/format.py:836, in read_array(fp, allow_pickle, pickle_kwargs, max_header_size)
#     833 else:
#     834     if isfileobj(fp):
#     835         # We can use the fast fromfile() function.
# --> 836         array = numpy.fromfile(fp, dtype=dtype, count=count)
#     837     else:
#     838         # This is not a real file. We have to read it the
#     839         # memory-intensive way.
#    (...)
#     847         # not correctly instantiate zero-width string dtypes; see
#     848         # https://github.com/numpy/numpy/pull/6430
#     849         array = numpy.ndarray(count, dtype=dtype)
#
# KeyboardInterrupt:
