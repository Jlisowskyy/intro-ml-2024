# %% [markdown]
# # Generating Histograms From Audio Files
# Use this notebook to create spectrograms and then RGB histograms from `.wav` audio.
#
# - Audio is read and optionally denoised.
# - A mel spectrogram is generated.
# - The spectrogram is saved as an image.
# - Then `generate_rgb_histogram` is invoked to show color distribution of the spectrogram.

# %% [markdown]
# ## Setup

# %%
from notebooks.setup_notebook_env import setup_notebook_env
setup_notebook_env()
# Out:
# Current working directory: C:\Users\pietr\Documents\studia\machine learning\intro ml nowy projekt\intro-ml-2024
# PyTorch version: 2.5.1+cu118
# Using device: cuda
# 'cuda'

# %% [markdown]
# ## Generate Histograms

# %%
# %matplotlib inline
from src.scripts.from_wav_to_histogram import process_directory

input_directory = "C:/Users/pietr/Documents/studia/machine learning/intro ml nowy projekt/intro-ml-2024/datasets/kaggle/train/train/audio/bed"  # A directory containing .wav files
process_directory(input_directory)

print("Done generating spectrograms and histograms.")
# Out:
# Spectrogram: Done with 00f0204f_nohash_0.wav, 0
# Spectrogram: Done with 0a7c2a8d_nohash_0.wav, 1
# Spectrogram: Done with 0b09edd3_nohash_0.wav, 2
# Spectrogram: Done with 0b56bcfe_nohash_0.wav, 3
# Done with creating spectrograms
# Generating RGB histogram of the spectrogram:  C:/Users/pietr/Documents/studia/machine learning/intro ml nowy projekt/intro-ml-2024/datasets/kaggle/train/train/audio/bed\_spectrograms\00f0204f_nohash_0.png
# Generating RGB histogram of the spectrogram:  C:/Users/pietr/Documents/studia/machine learning/intro ml nowy projekt/intro-ml-2024/datasets/kaggle/train/train/audio/bed\_spectrograms\0a7c2a8d_nohash_0.png
# Generating RGB histogram of the spectrogram:  C:/Users/pietr/Documents/studia/machine learning/intro ml nowy projekt/intro-ml-2024/datasets/kaggle/train/train/audio/bed\_spectrograms\0b09edd3_nohash_0.png
# ...
